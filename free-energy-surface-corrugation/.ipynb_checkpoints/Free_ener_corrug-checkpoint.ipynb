# %%
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.colors as colors
import matplotlib.ticker as ticker
from matplotlib.colors import ListedColormap
import matplotlib.image as mpimg
from matplotlib.colors import LogNorm
plt.rcParams['text.usetex'] = True

# %%
df = pd.read_csv('free_py.dat', header = 0, delim_whitespace=True ).reset_index()
x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(y, x)
z = df.iloc[:,2].to_numpy()
Z = np.reshape(z, (len(x), len(y)))

fig, ax = plt.subplots()
pcm = ax.pcolormesh(X, Y, Z, norm=colors.PowerNorm(gamma=0.6),
                       cmap='RdGy',shading='flat')
fig.colorbar(pcm, ax=ax, extend='max')
# plt.axis([0,3,0,3])
plt.savefig('gra_single_free_ener.pdf')

# %%
from mpl_toolkits import mplot3d

import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.contour3D(X, Y, Z, 50, cmap='PuBu')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

ax.axis('off')
# ax.view_init(10, 60)
# Out:
# (-0.488268, 10.253627999999999, -0.8492809033028949, 17.83489896936079)

# %%
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap='PuBu', edgecolor='none')

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
# subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.35,
#                 hspace=1)
a = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('free_py_hex.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()*1000
z_max = max(z)
print(z_max)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,vmin=0.001, vmax=z_max, extent=extent_gra)
# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

plt.savefig('gra_single/free_ener_hexagon.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# 9.76362268769634

# %%
fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
# subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.35,
#                 hspace=1)
a = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('../free_py.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()*1000
z_max = max(z)
print(z_max)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,vmin=0.001, vmax=z_max, extent=extent_gra)
# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

# plt.savefig('gra_single/free_ener_gra.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# 11.448078113659703

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 1,frameon=True, figsize = (8,8),sharey=True, sharex=True)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0,
                hspace=0)
a = 1
plot_alpha = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('gra_single/freeO_hex.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
print(min(z*1000), max(z*1000))
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra_O = ax[0].imshow(Z*1000, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.1, vmax=11), extent=extent_gra)

df = pd.read_csv('gra_single/freeH_hex.dat', header = 0, delim_whitespace=True ).reset_index()
x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
print(min(z*1000), max(z*1000))
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra_H = ax[1].imshow(Z*1000, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.1, vmax=11), extent=extent_gra)


cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra_O,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax[0].tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
ax[1].tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
ax[0].set_title('$\mathrm{O}$', fontsize = 14)
ax[1].set_title('$\mathrm{H}$', fontsize = 14)
cb.ax.tick_params(labelsize=14) 

# plt.savefig('gra_single/free_ener_gra_OH2.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# -0.0 9.76362268769634
# -0.0 4.3994103548849965

# %%
my_cmap = colors.LinearSegmentedColormap.from_list("", ["gold", "cornflowerblue", "darkslateblue"])

# my_cmap = colors.LinearSegmentedColormap.from_list("", [ "darkslateblue", "royalblue","mediumturquoise","lightsalmon","gold" ])

plot_alpha = 1

fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
a = 1
# my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
# my_cmap[:,0:3] *= a 
# my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('free_py_hex.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()*1000
z_max = max(z)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=1, vmax=z_max), extent=extent_gra)
# gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=1, vmax=z_max), extent=extent_gra)

# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

plt.savefig('gra_single/free_ener_hexagon1.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %%
# img_gra = mpimg.imread("gra_cropped_transparent.png")
# plt.imshow(img, alpha=0.1,interpolation='bilinear')
# pic_alpha = 1
plot_alpha = 1
# make these smaller to increase the resolution
# dx, dy = 0.001, 0.001
# x = np.arange(0, 2.6, dx)
# y = np.arange(0, 4.4, dy)
# X_gra, Y_gra = np.meshgrid(x, y)

# when layering multiple images, the images need to have the same
# extent.  This does not mean they need to have the same shape, but
# they both need to render to the same coordinate system determined by
# xmin, xmax, ymin, ymax.  Note if you use different interpolations
# for the images their apparent extent could be different due to
# interpolation edge effects


fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
# subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.35,
#                 hspace=1)
a = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('gra_single/free_py.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
z_max = max(z)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.001, vmax=z_max), extent=extent_gra)
# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

# plt.savefig('gra_single/free_ener_gra.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %%
fig, ax = plt.subplots(ncols = 2, nrows = 1,frameon=True, figsize = (8,8),sharey=True, sharex=True)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0,
                hspace=0)
a = 1
plot_alpha = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('gra_single/free_py.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
print(min(z*1000), max(z*1000))
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra_O = ax[0].imshow(Z*1000, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.1, vmax=11), extent=extent_gra)

df = pd.read_csv('gra_single/free_H.dat', header = 0, delim_whitespace=True ).reset_index()
x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
print(min(z*1000), max(z*1000))
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra_H = ax[1].imshow(Z*1000, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.1, vmax=11), extent=extent_gra)


cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra_O,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax[0].tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
ax[1].tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
ax[0].set_title('$\mathrm{O}$', fontsize = 14)
ax[1].set_title('$\mathrm{H}$', fontsize = 14)
cb.ax.tick_params(labelsize=14) 

plt.savefig('gra_single/free_ener_gra_OH2.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# -0.0 10.290135781467978
# -0.0 4.527630895882379

# %%
# img_gra = mpimg.imread("gra_cropped_transparent.png")
# plt.imshow(img, alpha=0.1,interpolation='bilinear')
# pic_alpha = 1
plot_alpha = 1
# make these smaller to increase the resolution
# dx, dy = 0.001, 0.001
# x = np.arange(0, 2.6, dx)
# y = np.arange(0, 4.4, dy)
# X_gra, Y_gra = np.meshgrid(x, y)

# when layering multiple images, the images need to have the same
# extent.  This does not mean they need to have the same shape, but
# they both need to render to the same coordinate system determined by
# xmin, xmax, ymin, ymax.  Note if you use different interpolations
# for the images their apparent extent could be different due to
# interpolation edge effects


fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
# subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.35,
#                 hspace=1)
a = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('hbn_single/free_py.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
z_max = max(z)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.001, vmax=z_max), extent=extent_gra)
# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

plt.savefig('hbn_single/free_ener_hbn.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %%
# img_gra = mpimg.imread("gra_cropped_transparent.png")
# plt.imshow(img, alpha=0.1,interpolation='bilinear')
# pic_alpha = 1
plot_alpha = 1
# make these smaller to increase the resolution
# dx, dy = 0.001, 0.001
# x = np.arange(0, 2.6, dx)
# y = np.arange(0, 4.4, dy)
# X_gra, Y_gra = np.meshgrid(x, y)

# when layering multiple images, the images need to have the same
# extent.  This does not mean they need to have the same shape, but
# they both need to render to the same coordinate system determined by
# xmin, xmax, ymin, ymax.  Note if you use different interpolations
# for the images their apparent extent could be different due to
# interpolation edge effects


fig, ax = plt.subplots(ncols = 1, nrows = 1,frameon=True, figsize = (6,6),sharey=False, sharex=False)
# subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.35,
#                 hspace=1)
a = 1
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

df = pd.read_csv('mos_single/free_py.dat', header = 0, delim_whitespace=True ).reset_index()

x = df.iloc[:, 0].drop_duplicates()
y = df.iloc[:, 1].drop_duplicates()
X, Y = np.meshgrid(x, y)
z = df.iloc[:, 2].to_numpy()
z_max = max(z)
Z = np.reshape(z, (len(x), len(y))).T
extent_gra = np.min(x), np.max(x), np.min(y), np.max(y)
gra = ax.imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.001, vmax=z_max), extent=extent_gra)
# ax[0].imshow(img_gra, alpha=pic_alpha, interpolation='bilinear',
#                  extent=extent_gra)

cbar_ax = fig.add_axes([1.02, 0.38, 0.05, 0.29])
cb = plt.colorbar(gra,cax=cbar_ax)
tick_locator = ticker.MaxNLocator(nbins=15)
cb.locator = tick_locator
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 16)
ax.tick_params(direction='out', grid_alpha=0.2, labelsize = 16)
cb.ax.tick_params(labelsize=14) 

plt.savefig('mos_single/free_ener_mos1.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{hBN}$', '$\mathrm{graphene}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{graphene}$', '$\mathrm{hBN}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$\n$\mathrm{MoS_2}$','$\mathrm{MoS_2}$\n$\mathrm{graphene}$','$\mathrm{MoS_2}$\n$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (15, 7.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.25,
                hspace=0.1)
a = 0.95
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
# my_cmap = plt.cm.bone_r(np.arange(plt.cm.bone_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)

for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
#         print(label)
        df = pd.read_csv('{}/free_py.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        z = df.iloc[:, 2].to_numpy()
#         print(max(z))
        Z = np.reshape(z, (len(x), len(y))).T
        extent = np.min(x), np.max(x), np.min(y), np.max(y)
        if bot == 'mos_single':
            mos = ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.001, vmax=0.06), extent=extent)
        else:
            ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=0.001, vmax=0.06), extent=extent)
        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        
#Cbar settings
cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=16) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)
plt.savefig('free_ener_ALL1.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %% [markdown]
# # HEXAGON Oxygens

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{hBN}$', '$\mathrm{graphene}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{graphene}$', '$\mathrm{hBN}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$\n$\mathrm{MoS_2}$','$\mathrm{MoS_2}$\n$\mathrm{graphene}$','$\mathrm{MoS_2}$\n$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (15, 7.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.25,
                hspace=0.1)
a = 0.95
my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
# my_cmap = plt.cm.bone_r(np.arange(plt.cm.bone_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)
vmax = 35
vmin = 1
for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
#         print(label)
        df = pd.read_csv('{}/freeO_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        z = df.iloc[:, 2].to_numpy() *1000
        print(min(z), max(z))
        Z = np.reshape(z, (len(x), len(y))).T
        extent = np.min(x), np.max(x), np.min(y), np.max(y)
        if bot == 'mos_single':
            mos = ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=vmin, vmax=vmax), extent=extent)
        else:
            ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=vmin, vmax=vmax), extent=extent)
        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        
#Cbar settings
cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=16) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)
plt.savefig('free_ener_ALL-Oxygens.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# -0.0 9.76362268769634
# -0.0 8.394612374354475
# -0.0 13.43740114860355
# -0.0 10.41356384028937
# -0.0 17.830532271908496
# -0.0 20.014634878831888
# -0.0 16.619439534118357
# -0.0 18.23198293447486
# -0.0 32.747450257650335
# -0.0 27.661407792982917
# -0.0 28.687305003164788
# -0.0 28.95801931992695

# %% [markdown]
# # HEXAGON Hydrogens

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{hBN}$', '$\mathrm{graphene}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{graphene}$', '$\mathrm{hBN}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$\n$\mathrm{MoS_2}$','$\mathrm{MoS_2}$\n$\mathrm{graphene}$','$\mathrm{MoS_2}$\n$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (15, 7.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.25,
                hspace=0.1)
a = 0.95
my_cmap = plt.cm.RdGy(np.arange(plt.cm.RdGy.N))
# my_cmap = plt.cm.bone_r(np.arange(plt.cm.bone_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)
vmax = 15
vmin = 0.1
for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
#         print(label)
        df = pd.read_csv('{}/freeH_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        z = df.iloc[:, 2].to_numpy() *1000
        print(min(z), max(z))
        Z = np.reshape(z, (len(x), len(y))).T
        extent = np.min(x), np.max(x), np.min(y), np.max(y)
        if bot == 'mos_single':
            mos = ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=vmin, vmax=vmax), extent=extent)
        else:
            ax[idx_row,idx_col].imshow(Z, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha,norm=LogNorm(vmin=vmin, vmax=vmax), extent=extent)
        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        
#Cbar settings
cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=16) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)
plt.savefig('free_ener_ALL-Hydrogens.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# -0.0 4.3994103548849965
# -0.0 3.7240001509727865
# -0.0 5.132158652922353
# -0.0 4.697997139656436
# -0.0 11.84415097585129
# -0.0 10.70366868994402
# -0.0 7.712051066305958
# -0.0 11.177501418184804
# -0.0 13.90325807088637
# -0.0 11.785354891882715
# -0.0 11.858711541873058
# -0.0 9.67350903356841

# %% [markdown]
# # COMBINING

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{graphene}$', '$\mathrm{graphene}$\n$\mathrm{hBN}$', '$\mathrm{graphene}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{hBN}$', '$\mathrm{hBN}$\n$\mathrm{graphene}$', '$\mathrm{hBN}$\n$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$\n$\mathrm{MoS_2}$','$\mathrm{MoS_2}$\n$\mathrm{graphene}$','$\mathrm{MoS_2}$\n$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (15, 7.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0.16, bottom=0.08, right=1, top=0.97, wspace=0.25,
                hspace=0.1)
a = 1
# my_cmap = plt.cm.viridis_r(np.arange(plt.cm.viridis_r.N))
# # my_cmap = plt.cm.bone_r(np.arange(plt.cm.bone_r.N))
# my_cmap[:,0:3] *= a 
# my_cmap = ListedColormap(my_cmap)
my_cmap = colors.LinearSegmentedColormap.from_list("", ["gold", "cornflowerblue", "darkslateblue"])
vmaxO = 35
vmaxH = 15
vminO = 1
vminH = 0.1
for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
        df = pd.read_csv('{}/freeO_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        zO = df.iloc[:, 2].to_numpy() *1000
        df = pd.read_csv('{}/freeH_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        zH = df.iloc[:, 2].to_numpy() *1000
        print('max O: ', max(zO), 'max H: ', max(zH))
        ZO = np.reshape(zO[:int(zO.shape[0]/2)], (int(len(x)/2), len(y))).T
        ZH = np.reshape(zH[int(zO.shape[0]/2):], (int(len(x)/2), len(y))).T
        half = int(zH.shape[0]/2)
        extentO = np.min(x), np.max(x)/2, np.min(y), np.max(y)
        extentH = np.max(x)/2, np.max(x), np.min(y), np.max(y)
        if bot == 'mos_single':
            mos_O = ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            mos_H = ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        else:
            ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        ax[idx_row,idx_col].plot((x[half]-0.1,x[half]-0.1) , (0, Y[-1][-1]), lw=1, c='black')

        
# #Cbar settings H
cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos_O, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=16) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F_H}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)

# # #Cbar settings O
# cbar_ax = fig.add_axes([0.05, 0.11, 0.035, 0.825])
# cb = plt.colorbar(mos_O, cax=cbar_ax)
# # tick_locator = ticker.MaxNLocator(nbins=15)
# # cb.locator = tick_locator
# cb.set_alpha(plot_alpha)
# cb.draw_all()
# cb.ax.tick_params(labelsize=16) 
# cbar_ax.set_ylabel(r'$\mathrm{\Delta F_O}$', rotation=90, labelpad=-1, y=0.5, fontsize = 18)
plt.savefig('free_ener_OH.pdf', transparent=True, dpi=100,bbox_inches='tight')
# Out:
# max O:  9.76362268769634 max H:  4.3994103548849965
# max O:  8.394612374354475 max H:  3.7240001509727865
# max O:  13.43740114860355 max H:  5.132158652922353
# max O:  10.41356384028937 max H:  4.697997139656436
# max O:  17.830532271908496 max H:  11.84415097585129
# max O:  20.014634878831888 max H:  10.70366868994402
# max O:  16.619439534118357 max H:  7.712051066305958
# max O:  18.23198293447486 max H:  11.177501418184804
# max O:  32.747450257650335 max H:  13.90325807088637
# max O:  27.661407792982917 max H:  11.785354891882715
# max O:  28.687305003164788 max H:  11.858711541873058
# max O:  28.95801931992695 max H:  9.67350903356841

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$/$\mathrm{graphene}$', '$\mathrm{graphene}$/$\mathrm{hBN}$', '$\mathrm{graphene}$/$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$/$\mathrm{hBN}$', '$\mathrm{hBN}$/$\mathrm{graphene}$', '$\mathrm{hBN}$/$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$/$\mathrm{MoS_2}$','$\mathrm{MoS_2}$/$\mathrm{graphene}$','$\mathrm{MoS_2}$/$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (15, 7.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0, bottom=0.0, right=1, top=0.99, wspace=0.2,
                hspace=0.0)
a = 0.9
my_cmap = plt.cm.RdGy_r(np.arange(plt.cm.RdGy_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)
# my_cmap = colors.LinearSegmentedColormap.from_list("", ["gold", "cornflowerblue", "darkslateblue"])
vmaxO = 35
vmaxH = 15
vminO = 1
vminH = 0.1
for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
        df = pd.read_csv('{}/freeO_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        zO = df.iloc[:, 2].to_numpy() *1000
        df = pd.read_csv('{}/freeH_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        zH = df.iloc[:, 2].to_numpy() *1000
#         print('max O: ', max(zO), 'max H: ', max(zH))
        ZO = np.reshape(zO[:int(zO.shape[0]/2)], (int(len(x)/2), len(y))).T
        ZH = np.reshape(zH[int(zO.shape[0]/2):], (int(len(x)/2), len(y))).T
        half = int(zH.shape[0]/2)
        extentO = np.min(x), np.max(x)/2, np.min(y), np.max(y)
        extentH = np.max(x)/2, np.max(x), np.min(y), np.max(y)
        if bot == 'mos_single':
            mos_O = ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            mos_H = ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        else:
            ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        ax[idx_row,idx_col].plot((x[half],x[half]) , (0, Y[-1][-1]), lw=1, c='black')
        ax[idx_row,idx_col].set_yticklabels([])
        ax[idx_row,idx_col].set_xticklabels([])

        
# #Cbar settings H
cbar_ax = fig.add_axes([1.02, 0.08, 0.02, 0.825])
# cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos_O, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=18) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)
plt.savefig('free_ener_OH.pdf', transparent=True, dpi=100,bbox_inches='tight')

# %%
  from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
systems = (['gra_single', 'gra_bi', 'hbn_gra', 'mos_gra'],['hbn_single', 'hbn_bi', 'gra_hbn', 'mos_hbn'],['mos_single', 'mos_bi', 'gra_mos', 'hbn_mos'])
labels = (['$\mathrm{graphene}$', '$\mathrm{graphene}$/$\mathrm{graphene}$', '$\mathrm{graphene}$/$\mathrm{hBN}$', '$\mathrm{graphene}$/$\mathrm{MoS_2}$'], 
          ['$\mathrm{hBN}$', '$\mathrm{hBN}$/$\mathrm{hBN}$', '$\mathrm{hBN}$/$\mathrm{graphene}$', '$\mathrm{hBN}$/$\mathrm{MoS_2}$'], 
          ['$\mathrm{MoS_2}$', '$\mathrm{MoS_2}$/$\mathrm{MoS_2}$','$\mathrm{MoS_2}$/$\mathrm{graphene}$','$\mathrm{MoS_2}$/$\mathrm{hBN}$' ])

fig, ax = plt.subplots(ncols = 4, nrows = 3, figsize = (8, 6.5),sharey=False, sharex=False)
plt.subplots_adjust(left=0, bottom=0.0, right=1, top=0.99, wspace=0.2,
                hspace=0.25)
a = 0.9
my_cmap = plt.cm.RdGy_r(np.arange(plt.cm.RdGy_r.N))
my_cmap[:,0:3] *= a 
my_cmap = ListedColormap(my_cmap)
# my_cmap = colors.LinearSegmentedColormap.from_list("", ["gold", "cornflowerblue", "darkslateblue"])
vmaxO = 35
vmaxH = 15
vminO = 1
vminH = 0.1
for idx_row, (top, label_top) in enumerate(zip(systems, labels)):
    for idx_col, (bot, label) in enumerate(zip(top, label_top)):
        df = pd.read_csv('{}/freeO_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        x = df.iloc[:, 0].drop_duplicates()
        y = df.iloc[:, 1].drop_duplicates()
        X, Y = np.meshgrid(x, y)
        zO = df.iloc[:, 2].to_numpy() *1000
        df = pd.read_csv('{}/freeH_hex.dat'.format(bot), header = 0, delim_whitespace=True ).reset_index()
        zH = df.iloc[:, 2].to_numpy() *1000
#         print('max O: ', max(zO), 'max H: ', max(zH))
        ZO = np.reshape(zO[:int(zO.shape[0]/4)], (int(len(x)/4), len(y))).T
        ZH = np.reshape(zH[int(zO.shape[0]/4):int(zO.shape[0]/2)], (int(len(x)/4), len(y))).T
        half = int(zH.shape[0]/4)
        extentO = np.min(x), np.max(x)/4, np.min(y), np.max(y)
        extentH = np.max(x)/4, np.max(x)/2, np.min(y), np.max(y)
        
        if bot == 'mos_single':
            mos_O = ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            mos_H = ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        else:
            ax[idx_row,idx_col].imshow(ZO, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminO, vmax=vmaxO), extent=extentO)
            ax[idx_row,idx_col].imshow(ZH, cmap=my_cmap, interpolation='bessel', alpha = plot_alpha, norm=LogNorm(vmin=vminH, vmax=vmaxO), extent=extentH)
        
        df_mat = pd.read_csv('{}_wrapped.xyz'.format(bot), header = 0, delim_whitespace=True )
        C = df_mat.loc[(df_mat['Name'] == 'C')];
        B = df_mat.loc[(df_mat['Name'] == 'B')]; N = df_mat.loc[(df_mat['Name'] == 'N')]
        Mo = df_mat.loc[(df_mat['Name'] == 'Mo')]; S = df_mat.loc[(df_mat['Name'] == 'S')]
        
        C.plot(kind='scatter', x = "x", y = "y", ax = ax[idx_row,idx_col], c='cyan', ec='black', lw=0.6, s=50, xlim=(np.min(x),np.max(x)/2), ylim=(np.min(y),np.max(y)))
        B.plot(kind='scatter', x = "x", y = "y", ax = ax[idx_row,idx_col], c='pink', ec='black', lw=0.6, s=80, xlim=(np.min(x),np.max(x)/2), ylim=(np.min(y),np.max(y)))
        N.plot(kind='scatter', x = "x", y = "y", ax = ax[idx_row,idx_col], c='blue', ec='black', lw=0.6, s=50, xlim=(np.min(x),np.max(x)/2), ylim=(np.min(y),np.max(y)) )
        Mo.plot(kind='scatter', x = "x", y = "y", ax = ax[idx_row,idx_col], c='coral', ec='black', lw=0.6, s=90, xlim=(np.min(x),np.max(x)/2), ylim=(np.min(y),np.max(y)) )
        S.plot(kind='scatter', x = "x", y = "y", ax = ax[idx_row,idx_col], c='gold', ec='black', lw=0.6, s=50, xlim=(np.min(x),np.max(x)/2), ylim=(np.min(y),np.max(y)) )

        ax[idx_row,idx_col].tick_params(direction='out', grid_alpha=2, labelsize = 13)
        ax[idx_row,idx_col].xaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].yaxis.set_major_locator(plt.MaxNLocator(4))
        ax[idx_row,idx_col].set_title(r'{}'.format(label), fontsize = 16)
        ax[idx_row,idx_col].plot((x[half],x[half]) , (0, Y[-1][-1]), lw=1, c='black')
        ax[idx_row,idx_col].set_yticklabels([])
        ax[idx_row,idx_col].set_xticklabels([])

        
# #Cbar settings H
cbar_ax = fig.add_axes([1.02, 0.08, 0.02, 0.825])
# cbar_ax = fig.add_axes([1.05, 0.11, 0.035, 0.825])
cb = plt.colorbar(mos_O, cax=cbar_ax)
# tick_locator = ticker.MaxNLocator(nbins=15)
# cb.locator = tick_locator
cb.set_alpha(plot_alpha)
cb.draw_all()
cb.ax.tick_params(labelsize=18) 
cbar_ax.set_ylabel(r'$\mathrm{\Delta F, meV}$', rotation=270, labelpad=20, y=0.5, fontsize = 18)
plt.savefig('free_ener_OH.pdf', transparent=True, dpi=100,bbox_inches='tight')
